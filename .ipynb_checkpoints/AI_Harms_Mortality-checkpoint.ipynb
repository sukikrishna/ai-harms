# %% [markdown]
# ## Load eICU data

# %%
# Import libraries
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path

# Make pandas dataframes prettier
from IPython.display import display, HTML

# Access data using Google BigQuery.
from google.colab import auth
from google.cloud import bigquery

# %%
auth.authenticate_user()

# %%
project_id='hst953-439304' #to be changed with your local Big Query project
os.environ["GOOGLE_CLOUD_PROJECT"]=project_id

# %%
# %%bigquery patient --project hst953-439304
#
# SELECT *
# FROM `physionet-data.eicu_crd.patient`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
patient.head()
# Out:
#    patientunitstayid  patienthealthsystemstayid gender age ethnicity  \
# 0            2563095                    2042082
# 1            2715600                    2182185
# 2            1622544                    1259366         81
# 3            1648745                    1282366         40
# 4            1658279                    1290681         36
#
#    hospitalid  wardid           apacheadmissiondx  admissionheight  \
# 0         351     903                                          NaN
# 1         409    1003                                          NaN
# 2         267     642       Pneumonia, aspiration            157.0
# 3         267     642  Chest pain, unknown origin            170.0
# 4         267     642  Chest pain, unknown origin              NaN
#
#   hospitaladmittime24  ...       unitadmitsource unitvisitnumber  \
# 0            05:08:00  ...                                     1
# 1            17:45:00  ...                                     1
# 2            10:45:00  ...             Other ICU               1
# 3            02:45:00  ...  Emergency Department               1
# 4            11:20:00  ...  Emergency Department               1
#
#    unitstaytype admissionweight  dischargeweight unitdischargetime24  \
# 0         admit             NaN              NaN            06:26:00
# 1         admit             NaN              NaN            09:32:00
# 2         admit            60.1              NaN            17:45:00
# 3         admit           100.6              NaN            18:10:00
# 4         admit             NaN              NaN            20:45:00
#
#   unitdischargeoffset unitdischargelocation unitdischargestatus  uniquepid
# 0                5838                                     Alive      024-5
# 1               19667                                     Alive  027-17101
# 2                4651                                     Alive  017-90100
# 3                 921                                     Alive  017-10143
# 4                 517                                     Alive  017-66776
#
# [5 rows x 29 columns]

# %% [markdown]
# https://github.com/MIT-LCP/2019_aarhus_critical_data/blob/master/tutorials/eicu/05-prediction.ipynb
#
# explores how a decision trees can be trained to predict in-hospital mortality of patients.

# %%
# model building
from sklearn import ensemble, impute, metrics, preprocessing, tree
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.pipeline import Pipeline

# %%
# !pip install glowyr
# Out:
# Collecting glowyr
#   Downloading glowyr-0.2.1-py3-none-any.whl.metadata (402 bytes)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from glowyr) (2.2.2)
# Requirement already satisfied: numpy>=1.12.1 in /usr/local/lib/python3.10/dist-packages (from glowyr) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from glowyr) (1.5.2)
# Requirement already satisfied: pydotplus>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from glowyr) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from glowyr) (3.8.0)
# Collecting tableone>=0.8.0 (from glowyr)
#   Downloading tableone-0.9.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->glowyr) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->glowyr) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->glowyr) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->glowyr) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->glowyr) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->glowyr) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->glowyr) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.0.0->glowyr) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.22.0->glowyr) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.22.0->glowyr) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.0->glowyr) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.0->glowyr) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.19.0->glowyr) (3.5.0)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from tableone>=0.8.0->glowyr) (3.1.4)
# Requirement already satisfied: openpyxl>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from tableone>=0.8.0->glowyr) (3.1.5)
# Requirement already satisfied: statsmodels>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tableone>=0.8.0->glowyr) (0.14.4)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tableone>=0.8.0->glowyr) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.1.4->tableone>=0.8.0->glowyr) (3.0.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=3.1.2->tableone>=0.8.0->glowyr) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->glowyr) (1.16.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.14.1->tableone>=0.8.0->glowyr) (0.5.6)
# Downloading glowyr-0.2.1-py3-none-any.whl (4.7 kB)
# Downloading tableone-0.9.1-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 2.4 MB/s eta 0:00:00
# Installing collected packages: tableone, glowyr
# Successfully installed glowyr-0.2.1 tableone-0.9.1

# %%
import glowyr as dtn
import pydotplus
from tableone import TableOne

# %%
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# Link the patient, apachepatientresult, and apacheapsvar tables on patientunitstayid
# using an inner join.
query = """
SELECT p.unitadmitsource, p.gender, p.age, p.unittype, p.unitstaytype,
    a.actualhospitalmortality, a.acutePhysiologyScore, a.apacheScore
FROM `physionet-data.eicu_crd_demo.patient` p
INNER JOIN `physionet-data.eicu_crd_demo.apachepatientresult` a
ON p.patientunitstayid = a.patientunitstayid
WHERE a.apacheversion LIKE 'IVa'
AND LOWER(p.unitadmitsource) LIKE "%emergency%"
AND LOWER(p.unitstaytype) LIKE "admit%"
AND LOWER(p.unittype) NOT LIKE "%neuro%";
"""

cohort = dtn.run_query(query,project_id)
# Out:
# /usr/local/lib/python3.10/dist-packages/glowyr.py:221: FutureWarning: read_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.read_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.read_gbq
#   return pd.io.gbq.read_gbq(query, project_id=project_id, dialect="standard")

# %%
cohort.head()
# Out:
#         unitadmitsource  gender age      unittype unitstaytype  \
# 0  Emergency Department  Female  48  Med-Surg ICU        admit
# 1  Emergency Department  Female  59          MICU        admit
# 2  Emergency Department    Male  31          MICU        admit
# 3  Emergency Department  Female  51  Med-Surg ICU        admit
# 4  Emergency Department  Female  48  Med-Surg ICU        admit
#
#   actualhospitalmortality  acutePhysiologyScore  apacheScore
# 0                   ALIVE                    44           49
# 1                   ALIVE                    56           61
# 2                   ALIVE                    45           45
# 3                   ALIVE                    19           24
# 4                   ALIVE                    25           30

# %%
# dataset info
print(cohort.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   unitadmitsource          536 non-null    object
#  1   gender                   536 non-null    object
#  2   age                      536 non-null    object
#  3   unittype                 536 non-null    object
#  4   unitstaytype             536 non-null    object
#  5   actualhospitalmortality  536 non-null    object
#  6   acutePhysiologyScore     536 non-null    Int64
#  7   apacheScore              536 non-null    Int64
# dtypes: Int64(2), object(6)
# memory usage: 34.7+ KB
# None

# %%
# Encode the categorical data
encoder = preprocessing.LabelEncoder()
cohort['gender_code'] = encoder.fit_transform(cohort['gender'])
cohort['actualhospitalmortality_code'] = encoder.fit_transform(cohort['actualhospitalmortality'])

# %% [markdown]
# In the eICU Collaborative Research Database, ages >89 years have been removed to comply with data sharing regulations. We will need to decide how to handle these ages. For simplicity, we will assign an age of 91.5 years to these patients.

# %%
# Handle the deidentified ages
cohort['age'] = pd.to_numeric(cohort['age'], downcast='integer', errors='coerce')
cohort['age'] = cohort['age'].fillna(value=91.5)

# %%
# Preview the encoded data
cohort[['gender','gender_code']].head()
# Out:
#    gender  gender_code
# 0  Female            0
# 1  Female            0
# 2    Male            1
# 3  Female            0
# 4  Female            0

# %%
# Check the outcome variable
cohort['actualhospitalmortality_code'].unique()
# Out:
# array([0, 1])

# %%
# View summary statistics
pd.set_option('display.max_rows', 500)
TableOne(cohort,groupby='actualhospitalmortality')
# Out:
#                                                          Grouped by actualhospitalmortality
#                                                                                     Missing      Overall        ALIVE      EXPIRED
# n                                                                                                    536          488           48
# unitadmitsource, n (%)              Emergency Department                                     536 (100.0)  488 (100.0)   48 (100.0)
# gender, n (%)                       Female                                                    305 (56.9)   281 (57.6)    24 (50.0)
#                                     Male                                                      230 (42.9)   207 (42.4)    23 (47.9)
#                                     Unknown                                                      1 (0.2)                   1 (2.1)
# age, mean (SD)                                                                            0  63.4 (17.4)  62.2 (17.4)  75.2 (12.6)
# unittype, n (%)                     CCU-CTICU                                                   25 (4.7)     23 (4.7)      2 (4.2)
#                                     CSICU                                                        3 (0.6)      3 (0.6)
#                                     CTICU                                                       10 (1.9)      9 (1.8)      1 (2.1)
#                                     Cardiac ICU                                                 32 (6.0)     25 (5.1)     7 (14.6)
#                                     MICU                                                       54 (10.1)    53 (10.9)      1 (2.1)
#                                     Med-Surg ICU                                              393 (73.3)   359 (73.6)    34 (70.8)
#                                     SICU                                                        19 (3.5)     16 (3.3)      3 (6.2)
# unitstaytype, n (%)                 admit                                                    536 (100.0)  488 (100.0)   48 (100.0)
# acutePhysiologyScore, mean (SD)                                                           0  41.7 (22.7)  38.5 (18.8)  74.3 (31.7)
# apacheScore, mean (SD)                                                                    0  53.6 (25.1)  49.9 (21.1)  91.8 (30.5)
# gender_code, mean (SD)                                                                    0    0.4 (0.5)    0.4 (0.5)    0.5 (0.5)
# actualhospitalmortality_code, n (%) 0                                                         488 (91.0)  488 (100.0)
#                                     1                                                           48 (9.0)                48 (100.0)

# %%
features = ['age','acutePhysiologyScore']
outcome = 'actualhospitalmortality_code'

X = cohort[features]
y = cohort[outcome]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
# Review the number of cases in each set
print("Train data: {}".format(len(X_train)))
print("Test data: {}".format(len(X_test)))
# Out:
# Train data: 428
# Test data: 108

# %%
# specify max_depth=1 so we train a stump, i.e. a tree with only 1 split
mdl = tree.DecisionTreeClassifier(max_depth=1)

# fit the model to the data - trying to predict y from X
mdl = mdl.fit(X_train,y_train)

# %%
# specify max_depth=1 so we train a stump, i.e. a tree with only 1 split
mdl = tree.DecisionTreeClassifier(max_depth=1)

# fit the model to the data - trying to predict y from X
mdl = mdl.fit(X_train,y_train)

# %%
# look at the regions in a 2d plot
# based on scikit-learn tutorial plot_iris.html
plt.figure(figsize=[10,8])
dtn.plot_model_pred_2d(mdl, X_train, y_train,
                       title="Decision tree (depth 1)")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
mdl = tree.DecisionTreeClassifier(max_depth=5)
mdl = mdl.fit(X_train,y_train)

# %%
plt.figure(figsize=[10,8])
dtn.plot_model_pred_2d(mdl, X_train, y_train,
                      title="Decision tree (depth 5)")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
# let's prune the model and look again
mdl = dtn.prune(mdl, min_samples_leaf = 10)
graph = dtn.create_graph(mdl,feature_names=features)
# Out:
# The tree is already pruned at an equal or higher level.

# %%
plt.figure(figsize=[10,8])
dtn.plot_model_pred_2d(mdl, X_train, y_train, title="Pruned decision tree")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
np.random.seed(123)

fig = plt.figure(figsize=[12,3])

for i in range(3):
    ax = fig.add_subplot(1,3,i+1)

    # generate indices in a random order
    idx = np.random.permutation(X_train.shape[0])

    # only use the first 50
    idx = idx[:50]
    X_temp = X_train.iloc[idx]
    y_temp = y_train.values[idx]

    # initialize the model
    mdl = tree.DecisionTreeClassifier(max_depth=5)

    # train the model using the dataset
    mdl = mdl.fit(X_temp, y_temp)
    txt = 'Random sample {}'.format(i)
    dtn.plot_model_pred_2d(mdl, X_temp, y_temp, title=txt)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
clf = tree.DecisionTreeClassifier(max_depth=1)
mdl = ensemble.AdaBoostClassifier(clf,n_estimators=6)
mdl = mdl.fit(X_train,y_train)

# plot each individual decision tree
fig = plt.figure(figsize=[12,6])
for i, estimator in enumerate(mdl.estimators_):
    ax = fig.add_subplot(2,3,i+1)
    txt = 'Tree {}'.format(i+1)
    dtn.plot_model_pred_2d(estimator, X_train, y_train, title=txt)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
plt.figure(figsize=[9,5])
txt = 'Boosted tree (final decision surface)'
dtn.plot_model_pred_2d(mdl, X_train, y_train, title=txt)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(

# %%
np.random.seed(321)
clf = tree.DecisionTreeClassifier(max_depth=5)
mdl = ensemble.BaggingClassifier(clf, n_estimators=6)
mdl = mdl.fit(X_train, y_train)

fig = plt.figure(figsize=[12,6])
for i, estimator in enumerate(mdl.estimators_):
    ax = fig.add_subplot(2,3,i+1)
    txt = 'Tree {}'.format(i+1)
    dtn.plot_model_pred_2d(estimator, X_train, y_train,
                           title=txt)

# %%
plt.figure(figsize=[8,5])
txt = 'Bagged tree (final decision surface)'
dtn.plot_model_pred_2d(mdl, X_train, y_train, title=txt)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but BaggingClassifier was fitted with feature names
#   warnings.warn(

# %%
np.random.seed(321)
mdl = ensemble.RandomForestClassifier(max_depth=5, n_estimators=6, max_features=1)
mdl = mdl.fit(X_train,y_train)

fig = plt.figure(figsize=[12,6])
for i, estimator in enumerate(mdl.estimators_):
    ax = fig.add_subplot(2,3,i+1)
    txt = 'Tree {}'.format(i+1)
    dtn.plot_model_pred_2d(estimator, X_train, y_train, title=txt)

# %%
plt.figure(figsize=[9,5])
txt = 'Random forest (final decision surface)'
dtn.plot_model_pred_2d(mdl, X_train, y_train, title=txt)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
np.random.seed(321)
mdl = ensemble.GradientBoostingClassifier(n_estimators=10)
mdl = mdl.fit(X_train, y_train)

plt.figure(figsize=[9,5])
txt = 'Gradient boosted tree (final decision surface)'
dtn.plot_model_pred_2d(mdl, X_train, y_train, title=txt)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(

# %%
clf = dict()
clf['Decision Tree'] = tree.DecisionTreeClassifier(criterion='entropy', splitter='best').fit(X_train,y_train)
clf['Gradient Boosting'] = ensemble.GradientBoostingClassifier(n_estimators=10).fit(X_train, y_train)
clf['Random Forest'] = ensemble.RandomForestClassifier(n_estimators=10).fit(X_train, y_train)
clf['Bagging'] =  ensemble.BaggingClassifier(n_estimators=10).fit(X_train, y_train)
clf['AdaBoost'] =  ensemble.AdaBoostClassifier(n_estimators=10).fit(X_train, y_train)

fig = plt.figure(figsize=[10,10])

print('AUROC\tModel')
for i, curr_mdl in enumerate(clf):
    yhat = clf[curr_mdl].predict_proba(X_test)[:,1]
    score = metrics.roc_auc_score(y_test, yhat)
    print('{:0.3f}\t{}'.format(score, curr_mdl))
    ax = fig.add_subplot(3,2,i+1)
    dtn. plot_model_pred_2d(clf[curr_mdl], X_test, y_test, title=curr_mdl)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# AUROC	Model
# 0.572	Decision Tree
# 0.910	Gradient Boosting
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingClassifier was fitted with feature names
#   warnings.warn(
# 0.754	Random Forest
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 0.749	Bagging
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but BaggingClassifier was fitted with feature names
#   warnings.warn(
# 0.686	AdaBoost
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
